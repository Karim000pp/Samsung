# %%
import pyodbc
import pandas as pd

# %%
conn = pyodbc.connect(
    r"Driver={SQL Server};"
    r"Server=DESKTOP-0EH64EA\SQLEXPRESS;"
    r"Database=KarimProject;"
    r"Trusted_Connection=yes;"
)

# %%
pd.read_sql("SELECT name FROM sys.tables", conn)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18036\3521680879.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("SELECT name FROM sys.tables", conn)
#                 name
# 0         fact_sales
# 1      fact_shipment
# 2    fact_production
# 3   fact_procurement
# 4     fact_inventory
# 5       dim_supplier
# 6        dim_product
# 7       dim_facility
# 8           dim_date
# 9       dim_customer
# 10       sysdiagrams

# %%
fact_production = pd.read_sql("SELECT * FROM fact_production", conn)
fact_sales      = pd.read_sql("SELECT * FROM fact_sales", conn)
fact_shipment   = pd.read_sql("SELECT * FROM fact_shipment", conn)
fact_procurement =pd.read_sql("")
dim_product  = pd.read_sql("SELECT * FROM dim_product", conn)
dim_facility = pd.read_sql("SELECT * FROM dim_facility", conn)
dim_customer = pd.read_sql("SELECT * FROM dim_customer", conn)
dim_date     = pd.read_sql("SELECT * FROM dim_date", conn)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18036\2005869436.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   fact = pd.read_sql("SELECT * FROM fact_production", conn)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18036\2005869436.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   facility = pd.read_sql("SELECT * FROM dim_facility", conn)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18036\2005869436.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product = pd.read_sql("SELECT * FROM dim_product", conn)
# ...

# %%
facility.head()
# Out:
#    facility_id   facility_key         facility_name      country         city  \
# 0            1  FAC-KR-GUM-P1  Gumi Manufacturing 1  South Korea         Gumi
# 1            2  FAC-VN-TNG-P1     Thai Nguyen Plant      Vietnam  Thai Nguyen
# 2            3  FAC-KR-GUM-P3  Gumi Appliance Plant  South Korea         Gumi
# 3            4   WH-US-NJ-DC1         New Jersey DC          USA     Cranbury
# 4            5   WH-EU-PL-DC1             Poland DC       Poland       Warsaw
#
#    facility_type   specialization  annual_capacity
# 0  Manufacturing       Smartphone           850000
# 1  Manufacturing  Mobile Assembly          1500000
# 2  Manufacturing       Appliances           320000
# 3      Warehouse    North America           500000
# 4      Warehouse           Europe           520000

# %%
product.head()
# Out:
#    product_id     product_key      product_name    category product_line  \
# 0           1  SM-S928UZKAXAA  Galaxy S24 Ultra  Smartphone     Galaxy S
# 1           2  SM-S928UZAAXAA  Galaxy S24 Ultra  Smartphone     Galaxy S
# 2           3  SM-S921ULVAXAA        Galaxy S24  Smartphone     Galaxy S
# 3           4  SM-S911UCEAXAA        Galaxy S23  Smartphone     Galaxy S
# 4           5  SM-F946UZKAXAA    Galaxy Z Fold5  Smartphone     Galaxy Z
#
#     spec          color  unit_price  unit_cost  weight_kg  \
# 0  512GB  Phantom Black     1299.99     899.99       0.21
# 1  256GB  Titanium Gray     1199.99     839.99       0.15
# 2  256GB  Cobalt Violet      849.99     594.99       0.18
# 3  128GB          Cream      699.99     489.99       0.17
# 4  512GB  Phantom Black     1919.99    1343.99       0.22
#
#                                           Img
# 0  https://i.ibb.co/9Hv19S22/s24-Ultra.webp\r
# 1  https://i.ibb.co/9Hv19S22/s24-Ultra.webp\r
# ...

# %%
date.head()
# Out:
#    date_key   full_date  year  quarter  month month_name  week  day  \
# 0         1  2023-01-01  2023        1      1    January    52    1
# 1         2  2023-01-02  2023        1      1    January     1    2
# 2         3  2023-01-03  2023        1      1    January     1    3
# 3         4  2023-01-04  2023        1      1    January     1    4
# 4         5  2023-01-05  2023        1      1    January     1    5
#
#    day_of_week   day_name  is_weekend
# 0            6     Sunday           1
# 1            0     Monday           0
# 2            1    Tuesday           0
# 3            2  Wednesday           0
# 4            3   Thursday           0
